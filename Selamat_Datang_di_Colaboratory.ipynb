# %% [markdown]
# <a href="https://colab.research.google.com/github/irfanharfiansyah/REASONING-FUZZY/blob/main/Selamat_Datang_di_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <strong>Fuzzyfikasi</strong>
#
# Percobaan 1 : Fungsi Keanggotaan Variabel Input dan Output (Fuzzyfikasi)
#
# Terdapat dua buah variable input untuk studi kasus yang diambil pada jobsheet kali
# ini. Variabel input berupa kualitas makanan, dan kualitas pelayanan makanan akan
# menentukan output berupa jumlah tip yang diberikan dalam poin prosentase. Fungsi
# keanggotaan untuk studi kasus berikut akan dibagi menjadi tinggi, sedang, dan
# rendah.

# %%
 pip install -U scikit-fuzzy
# Out:
# ...
#      |████████████████████████████████| 993 kB 26.4 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=a2b2936f9dc71e1a8743dafbb703d93aa3e93fd45b0333e2328aebb6c5e8da23
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

#Generate Universe variables
# * Quality and service on subjective ranges [0, 10]
# * Tip has a range of [0, 25] in units of percentage points
x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip  = np.arange(0, 26, 1)

#Generate fuzzy membership functions
qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
serv_lo = fuzz.trimf(x_serv, [0, 0, 5])
serv_md = fuzz.trimf(x_serv, [0, 5, 10])
serv_hi = fuzz.trimf(x_serv, [5, 10, 10])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

#Visualize these universe and membership function
fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(8, 9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label="Great")
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_tip, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_tip, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_tip, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip amount')
ax2.legend()

# Turn off top/right axes
for ax in (ax0, ax1, ax2):
  ax.spines['top'].set_visible(False)
  ax.spines['right'].set_visible(False)
  ax.get_xaxis().tick_bottom()
  ax.get_yaxis().tick_left()

plt.tight_layout()

# %% [markdown]
# Pertanyaan
#
# 1) Apakah kegunaan import numpy pada kode program di atas?
#
# Jawab : Agar bisa mengakses sebuah library NumPy  yang fokus pada scientific computing. NumPy memiliki kemampuan untuk membentuk objek N-dimensional array. Berfungsi memudahkan operasi komputasi tipe data numerik seperti penjumlahan, pengurangan, perkalian, pangkat, dan operasi lainnya yang bisa diterapkan pada vektor atau matriks.
#
# 2) Apakah kegunaan import skfuzzy pada code program di atas?
#
# Jawab : Agar bisa menggunakan Scikit-Fuzzy yang terdapat kumpulan algoritma logika fuzzy yang dimaksudkan untuk digunakan dalam SciPy Stack , yang ditulis dalam bahasa komputasi Python, fuzzy Logic Toolbox untuk Python. Package ini mengimplementasikan banyak alat dan fungsi yang berguna untuk komputasi dan proyek yang melibatkan logika fuzzy.
#
# 3) Apakah fungsi import matplotlib.pyplot pada code program di atas?
#
# Jawab : Berfungsi untuk mengakases sebuah library Matplotlib ,visualisasi data multiplatform yang dibangun di atas array NumPy. matplotlib.pyplot terdapat kumpulan fungsi yang membuat beberapa perubahan pada gambar: misalnya, membuat gambar, membuat area plot dalam gambar, menambah label di plot dan lainnya
#
# 4) Jelaskan dengan detil tentang kode program mengenai visualisasi pada percobaan satu di
# atas!
#
# Jawab :
#
# ![image.png](data:image/png;base64,...)
#
# plt.subplots() yang berfungsi  mengembalikan tupel yang berisi gambar dan     objek sumbu. Jadi saat menggunakan fig, (ax, ax, ax) = plt.subplots() maka akan membongkar tuple ini ke dalam variabel fig dan ax, dan mengatur baris dan ukuran pada variabel fig
#
# --------
# ![image.png](data:image/png;base64,...)
#
# Penyesuaian pertama yang mungkin pada fungsi plot adalah mengontrol warna dan gaya garis pada masing variabel ax. Fungsi plt.plot() membutuhkan argumen tambahan yang dapat digunakan untuk menentukan ini. Untuk menyesuaikan warna, Anda dapat menggunakan keyword warna, yang menerima argumen string yang mewakili hampir semua warna yang bisa dibayangkan. Warnanya disini memaki format short color code (rgbcmyk). Dan selanjutnya terdapat plt.legend () yang berfungsi Ketika beberapa garis ditampilkan dalam satu sumbu, dapat berguna untuk membuat legenda plot yang menandai setiap jenis garis (Low, Medium, High).
#
# ----
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <strong>Fuzzyfikasi</strong>
#
# Percobaan 1 : Fungsi Keanggotaan Variabel Input dan Output (Fuzzyfikasi)
#
# Terdapat dua buah variable input untuk studi kasus yang diambil pada jobsheet kali
# ini. Variabel input berupa kualitas makanan, dan kualitas pelayanan makanan akan
# menentukan output berupa jumlah tip yang diberikan dalam poin prosentase. Fungsi
# keanggotaan untuk studi kasus berikut akan dibagi menjadi tinggi, sedang, dan
# rendah.
